# %% [markdown]
# <a href="https://colab.research.google.com/github/ar-1-su/leetcode-problems/blob/main/problem1523.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is problem no.1523--> Count Odd Number In An Interval Range:

class Solution:
    def countOdds(self, low: int, high: int) -> int:
       return (high+1)//2 - (low//2)
